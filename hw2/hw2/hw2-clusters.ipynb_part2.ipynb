# %%
import pandas as pd
import os
import numpy as np

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
## Задание 1
from sklearn.base import BaseEstimator, ClusterMixin
from collections import Counter
from scipy.spatial import distance_matrix


class DBSCAN(BaseEstimator, ClusterMixin):
    """
    Implement clustering algorithm according 
    """   
    
    def __init__(self, **kwargs):
        """
        Please add necessary algoritm parameters to class constructor.
        """
        self.eps     = kwargs['eps']     if 'eps'     in kwargs else 0.8
        self.min_pts = kwargs['min_pts'] if 'min_pts' in kwargs else 5
        self.label = None
        return
        
        
    def fit(self, x, y=None):
        """
        Use data matrix x to compute model parameters
        """
        DIST = distance_matrix(x,x) #
        self.DIST = DIST
        
        self.x_len = len(x)
        C = 0
        y = np.zeros(self.x_len )-1
        for ind in range(self.x_len):
            if y[ind] != -1:
                continue                                                   #Previously processed in inner loop
            Neighbors = np.where(DIST[ind,:]<self.eps)[0]                  #Find neighbors
            if len(Neighbors) < self.min_pts:                              #Density check
                y[ind] = 0                                                 #Label as Noise
                continue
            C = C+1                                                        #next cluster label
            y[ind] = C
            
            S = list(np.delete(Neighbors, np.argwhere(Neighbors == ind)))  #Neighbors to expand
            c = -1
            while(c<len(S)-1):                                             #Process every seed point
                c += 1                                                        
                ind2 = S[c]
                if y[ind2] == 0  : y[ind2] != C                            #Change Noise to border point
                if y[ind2] != -1 : continue
                    
                y[ind2] = C                                                #Label neighbor 
                Neighbors = np.where(DIST[ind2,:]<self.eps)[0]             #Find neighbors
                if len(Neighbors) >= self.min_pts:                         #Density check
                    S.extend(list(set(Neighbors) - set(S)))                #Add new neighbors to seed set
        self.label = y
        return self
    
    
    def predict(self, x, show_outliers = True):
        """
        Using computed model parameters predict cluster
        for all objects from x
        """
        if show_outliers:
            return self.label-1
        else:
            label = self.label
            for ind in np.where(self.label == 0)[0]:
                srt = self.DIST[ind, :]
                q = ind
                while(label[q] == 0):
                    q = np.argmin(srt)
                    srt[q] = 1e4
                label[ind] = label[q]
            return label-1
    
    def fit_predict(self, x, y=None, show_outliers = True):
        self.fit(x, y)
        return self.predict(x, show_outliers = show_outliers)

# %%
df = pd.read_csv('WDI_csv/WDIDATA.csv')

# %%
df = df.fillna(1488666)

# %%
YEAR = '2016'
t = df[df[YEAR] != 1488666]

# %%
t
# Out:
#        Country Name Country Code  \
# 61       Arab World          ARB
# 62       Arab World          ARB
# 63       Arab World          ARB
# 75       Arab World          ARB
# 77       Arab World          ARB
# 78       Arab World          ARB
# 81       Arab World          ARB
# 82       Arab World          ARB
# 83       Arab World          ARB
# 84       Arab World          ARB
# 97       Arab World          ARB
# 98       Arab World          ARB
# 107      Arab World          ARB
# 122      Arab World          ARB
# 132      Arab World          ARB
# 140      Arab World          ARB
# 147      Arab World          ARB
# 148      Arab World          ARB
# 152      Arab World          ARB
# 153      Arab World          ARB
# 165      Arab World          ARB
# 166      Arab World          ARB
# 205      Arab World          ARB
# 248      Arab World          ARB
# 262      Arab World          ARB
# 263      Arab World          ARB
# 264      Arab World          ARB
# 266      Arab World          ARB
# 267      Arab World          ARB
# 269      Arab World          ARB
# ...             ...          ...
# 409852     Zimbabwe          ZWE
# 409868     Zimbabwe          ZWE
# 409873     Zimbabwe          ZWE
# 409874     Zimbabwe          ZWE
# 409875     Zimbabwe          ZWE
# 409876     Zimbabwe          ZWE
# 409877     Zimbabwe          ZWE
# 409878     Zimbabwe          ZWE
# 409879     Zimbabwe          ZWE
# 409880     Zimbabwe          ZWE
# 409881     Zimbabwe          ZWE
# 409883     Zimbabwe          ZWE
# 409884     Zimbabwe          ZWE
# 409886     Zimbabwe          ZWE
# 409887     Zimbabwe          ZWE
# 409888     Zimbabwe          ZWE
# 409889     Zimbabwe          ZWE
# 409903     Zimbabwe          ZWE
# 409904     Zimbabwe          ZWE
# 409948     Zimbabwe          ZWE
# 409950     Zimbabwe          ZWE
# 409952     Zimbabwe          ZWE
# 409954     Zimbabwe          ZWE
# 409956     Zimbabwe          ZWE
# 409958     Zimbabwe          ZWE
# 409964     Zimbabwe          ZWE
# 409965     Zimbabwe          ZWE
# 409966     Zimbabwe          ZWE
# 409972     Zimbabwe          ZWE
# 409991     Zimbabwe          ZWE
#
#                                            Indicator Name  \
# 61      Age dependency ratio (% of working-age populat...
# 62      Age dependency ratio, old (% of working-age po...
# 63      Age dependency ratio, young (% of working-age ...
# 75      Agriculture value added per worker (constant 2...
# 77             Agriculture, value added (annual % growth)
# 78           Agriculture, value added (constant 2010 US$)
# 81                 Agriculture, value added (current US$)
# 82                Air transport, freight (million ton-km)
# 83                      Air transport, passengers carried
# 84      Air transport, registered carrier departures w...
# 97      Antiretroviral therapy coverage (% of people l...
# 98      Antiretroviral therapy coverage for PMTCT (% o...
# 107           Arms imports (SIPRI trend indicator values)
# 122     Average time to clear exports through customs ...
# 132              Battle-related deaths (number of people)
# 140                              Bird species, threatened
# 147     Bribery incidence (% of firms experiencing at ...
# 148                                Broad money (% of GDP)
# 152     Burden of customs procedure, WEF (1=extremely ...
# 153     Business extent of disclosure index (0=less di...
# 165     Charges for the use of intellectual property, ...
# 166     Charges for the use of intellectual property, ...
# 205            Claims on central government, etc. (% GDP)
# 248                Compulsory education, duration (years)
# 262     Cost of business start-up procedures (% of GNI...
# 263     Cost of business start-up procedures, female (...
# 264     Cost of business start-up procedures, male (% ...
# 266               Cost to export, border compliance (US$)
# 267          Cost to export, documentary compliance (US$)
# 269               Cost to import, border compliance (US$)
# ...                                                   ...
# 409852                              Tax payments (number)
# 409868           Terms of trade adjustment (constant LCU)
# 409873          Time required to build a warehouse (days)
# 409874         Time required to enforce a contract (days)
# 409875            Time required to get electricity (days)
# 409876  Time required to obtain an operating license (...
# 409877          Time required to register property (days)
# 409878           Time required to start a business (days)
# 409879   Time required to start a business, female (days)
# 409880     Time required to start a business, male (days)
# 409881  Time spent dealing with the requirements of go...
# 409883          Time to export, border compliance (hours)
# 409884     Time to export, documentary compliance (hours)
# 409886          Time to import, border compliance (hours)
# 409887     Time to import, documentary compliance (hours)
# 409888              Time to prepare and pay taxes (hours)
# 409889                 Time to resolve insolvency (years)
# 409903           Total tax rate (% of commercial profits)
# 409904                                   Trade (% of GDP)
# 409948  Unemployment, female (% of female labor force)...
# 409950  Unemployment, male (% of male labor force) (mo...
# 409952  Unemployment, total (% of total labor force) (...
# 409954  Unemployment, youth female (% of female labor ...
# 409956  Unemployment, youth male (% of male labor forc...
# 409958  Unemployment, youth total (% of total labor fo...
# 409964                                   Urban population
# 409965                      Urban population (% of total)
# 409966                 Urban population growth (annual %)
# 409972  Value lost due to electrical outages (% of sales)
# 409991  Women's share of population ages 15+ living wi...
#
#               Indicator Code          1960          1961          1962  \
# 61               SP.POP.DPND  8.820581e+01  8.964473e+01  9.094450e+01
# 62            SP.POP.DPND.OL  6.602746e+00  6.714313e+00  6.809043e+00
# 63            SP.POP.DPND.YG  8.146539e+01  8.277583e+01  8.394566e+01
# 75            EA.PRD.AGRI.KD  1.488666e+06  1.488666e+06  1.488666e+06
# 77         NV.AGR.TOTL.KD.ZG  1.488666e+06  1.488666e+06  1.488666e+06
# 78            NV.AGR.TOTL.KD  1.488666e+06  1.488666e+06  1.488666e+06
# 81            NV.AGR.TOTL.CD  1.488666e+06  1.488666e+06  1.488666e+06
# 82         IS.AIR.GOOD.MT.K1  1.488666e+06  1.488666e+06  1.488666e+06
# 83               IS.AIR.PSGR  1.488666e+06  1.488666e+06  1.488666e+06
# 84               IS.AIR.DPRT  1.488666e+06  1.488666e+06  1.488666e+06
# 97            SH.HIV.ARTC.ZS  1.488666e+06  1.488666e+06  1.488666e+06
# 98            SH.HIV.PMTC.ZS  1.488666e+06  1.488666e+06  1.488666e+06
# 107           MS.MIL.MPRT.KD  5.420000e+08  5.800000e+08  1.423000e+09
# 122           IC.CUS.DURS.EX  1.488666e+06  1.488666e+06  1.488666e+06
# 132              VC.BTL.DETH  1.488666e+06  1.488666e+06  1.488666e+06
# 140           EN.BIR.THRD.NO  1.488666e+06  1.488666e+06  1.488666e+06
# 147           IC.FRM.BRIB.ZS  1.488666e+06  1.488666e+06  1.488666e+06
# 148        FM.LBL.BMNY.GD.ZS  2.249595e+01  2.250148e+01  2.243561e+01
# 152           IQ.WEF.CUST.XQ  1.488666e+06  1.488666e+06  1.488666e+06
# 153           IC.BUS.DISC.XQ  1.488666e+06  1.488666e+06  1.488666e+06
# 165           BM.GSR.ROYL.CD  1.488666e+06  1.488666e+06  1.488666e+06
# 166           BX.GSR.ROYL.CD  1.488666e+06  1.488666e+06  1.488666e+06
# 205        FS.AST.CGOV.GD.ZS  4.083131e-01  3.031078e+00  4.972240e+00
# 248              SE.COM.DURS  1.488666e+06  1.488666e+06  1.488666e+06
# 262        IC.REG.COST.PC.ZS  1.488666e+06  1.488666e+06  1.488666e+06
# 263     IC.REG.COST.PC.FE.ZS  1.488666e+06  1.488666e+06  1.488666e+06
# 264     IC.REG.COST.PC.MA.ZS  1.488666e+06  1.488666e+06  1.488666e+06
# 266           IC.EXP.CSBC.CD  1.488666e+06  1.488666e+06  1.488666e+06
# 267           IC.EXP.CSDC.CD  1.488666e+06  1.488666e+06  1.488666e+06
# 269           IC.IMP.CSBC.CD  1.488666e+06  1.488666e+06  1.488666e+06
# ...                      ...           ...           ...           ...
# 409852           IC.TAX.PAYM  1.488666e+06  1.488666e+06  1.488666e+06
# 409868        NY.TTF.GNFS.KN  1.488666e+06  1.488666e+06  1.488666e+06
# ...              ...           ...           ...          ...
# 409852  5.100000e+01  5.100000e+01  5.100000e+01    1488666.0
# 409868  5.058116e+08  2.807627e+01  6.472467e+07    1488666.0
# 409873  4.480000e+02  4.480000e+02  2.380000e+02    1488666.0
# 409874  4.100000e+02  4.100000e+02  4.100000e+02    1488666.0
# 409875  1.060000e+02  1.060000e+02  1.060000e+02    1488666.0
# 409876  1.488666e+06  1.488666e+06  8.100000e+00    1488666.0
# 409877  3.600000e+01  3.600000e+01  3.600000e+01    1488666.0
# 409878  9.100000e+01  9.100000e+01  9.100000e+01    1488666.0
# 409879  9.100000e+01  9.100000e+01  9.100000e+01    1488666.0
# 409880  9.100000e+01  9.100000e+01  9.100000e+01    1488666.0
# 409881  1.488666e+06  1.488666e+06  3.200000e+00    1488666.0
# 409883  7.200000e+01  7.200000e+01  7.200000e+01    1488666.0
# 409884  9.900000e+01  9.900000e+01  9.900000e+01    1488666.0
# 409886  6.000000e+01  6.000000e+01  2.280000e+02    1488666.0
# 409887  8.100000e+01  8.100000e+01  8.100000e+01    1488666.0
# 409888  2.420000e+02  2.420000e+02  2.420000e+02    1488666.0
# 409889  3.300000e+00  3.300000e+00  3.300000e+00    1488666.0
# 409903  3.250000e+01  3.280000e+01  3.280000e+01    1488666.0
# 409904  6.330297e+01  6.020602e+01  6.047162e+01    1488666.0
# 409948  5.178000e+00  4.852000e+00  4.668000e+00    1488666.0
# 409950  5.086000e+00  5.362000e+00  5.487000e+00    1488666.0
# 409952  5.131000e+00  5.115000e+00  5.090000e+00    1488666.0
# 409954  9.417000e+00  9.388000e+00  9.407000e+00    1488666.0
# 409956  9.115000e+00  1.014600e+01  1.075000e+01    1488666.0
# 409958  9.257000e+00  9.790000e+00  1.012000e+01    1488666.0
# 409964  5.008948e+06  5.108108e+06  5.212852e+06    1488666.0
# 409965  3.250100e+01  3.237600e+01  3.227700e+01    1488666.0
# 409966  1.875147e+00  1.960317e+00  2.029803e+00    1488666.0
# 409972  1.488666e+06  1.488666e+06  6.100000e+00    1488666.0
# 409991  5.837759e+01  5.850271e+01  5.862769e+01    1488666.0
#
# [91214 rows x 62 columns]

# %%
df_f = {}
ttt = 0
for key, lst in t.groupby("Country Code"):
    df_f[key] = {}
    for ind, value in zip(lst['Indicator Name'], lst[YEAR]):
        df_f[key][ind] = value

# %%
g = pd.DataFrame.from_dict(df_f).T

# %%
g = g.fillna(1488666)

# %%
#How many NaN?
line = {}
for i in g.keys():
#     print(g[i])
    line[i] = len(g[i])-list(g[i]).count(1488666)

# %%
# for i in sorted(line.items(), key = lambda x:-x[1]):
#     print(i[0]+'\t'+str(i[1]))

# %%
plt.hist(line.values())
# Out:
# (array([ 293.,   10.,   60.,   51.,   64.,   91.,   62.,   26.,   85.,   97.]),
#  array([   1. ,   27.2,   53.4,   79.6,  105.8,  132. ,  158.2,  184.4,
#          210.6,  236.8,  263. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### Так как обучать метрические алгоритмы кластеризации на большом количестве фичей нельзя (рпоклятие размерности), возьмем только часть признаков GDP

# %% [markdown]
# План
# - Удалим страны(объединения), которых нет на карте
# - Уберем все редкие фичи
# - Оставим 5-10 полезных фичей

# %%
g_all = g.copy()

# %%
# features = [i[0] for i in filter(lambda x:x[1]>150 and x[1]<160,line.items())]
# import random 
features = sorted([i[0] for i in filter(lambda x:"GDP" in x[0], line.items())], key = lambda x:-line[x])[0:5]

# %%
df = pd.read_csv("Country_List_ISO_3166_Codes_Latitude_Longitude.csv")
a = set(t['Country Code'].unique())
b = set(df['Alpha-3 code'].unique())
countr_dct = {k:i for i,k in t[["Country Name","Country Code"]].get_values()}
# for i in a-b:
#     countr_dct(temp[i])
countries = df[df['Alpha-3 code'].isin(a & b)][['Alpha-3 code', "Latitude (average)", "Longitude (average)"]]

# %%
g = g_all[features]
g = g[g.index.isin(countr_dct.keys())]#'ABW'
g = g.replace(1488666, np.nan)

# %%
for i in features:
    g[i] = (g[i]-g[i].mean())/g[i].std()

# %%
g = g.replace(np.nan, g.mean())

# %%
y_predict = DBSCAN(eps = 0.5, min_samples = 1).fit_predict(g.get_values(), show_outliers = False)
# y_predict = KMeans(n_clusters=2).fit_predict(g.get_values())
Counter(y_predict)
# Out:
# Counter({0.0: 233, 1.0: 30})

# %%
df = pd.read_csv("Country_List_ISO_3166_Codes_Latitude_Longitude.csv")
a = set(t['Country Code'].unique())
b = set(df['Alpha-3 code'].unique())
countr_dct = {k:i for i,k in t[["Country Name","Country Code"]].get_values()}
# for i in a-b:
#     countr_dct(temp[i])
countries = df[df['Alpha-3 code'].isin(a & b)][['Alpha-3 code', "Latitude (average)", "Longitude (average)"]]

# %%
draw_lst = {}
draw_crunch = {}
for c, i in enumerate(g.index):
        if i in countries['Alpha-3 code'].get_values():
#             print(countries[countries['Alpha-3 code'] == i].get_values()[0])
            cname, lat, long = countries[countries['Alpha-3 code'] == i].get_values()[0]
            draw_lst[cname] = [lat, long, y_predict[c]]
            if y_predict[c] not in draw_crunch:
                draw_crunch[y_predict[c]] = [[lat, long]]
            else:
                draw_crunch[y_predict[c]].append([lat, long])

# %%
from collections import Counter
print(Counter(y_predict))
def get_color(i):
    if i==0:
        return "blue"
    if i==1:
        return "green"
    if i==2:
        return "yellow"
    if i==3:
        return "pink"
    if i==4:
        return "cyan"
#     if i==5:
#         return ""

    return "red"
# Out:
# Counter({0.0: 233, 1.0: 30})

# %%
from mpl_toolkits.basemap import Basemap
# from matplotlib import cm
from matplotlib.colors import LinearSegmentedColormap

import matplotlib.pyplot as plt
plt.figure(figsize = (16,12))
map = Basemap()

map.drawcoastlines()
map.drawcountries()
lst = draw_lst.values()
for clr, lst in draw_crunch.items():
#     if clr in [0,2]: continue
    map.plot([i[1] for i in lst], [i[0] for i in lst],'bo', c = get_color(clr), markersize=8)

plt.show()
plt.savefig('test.png')

# %%
for i in features:
    print(i)
# Out:
# GDP per person employed (constant 2011 PPP $)
# GDP (current US$)
# GDP per capita (current US$)
# Inflation, GDP deflator (annual %)
# GDP (constant 2010 US$)
